# %% [markdown]
# # Phase 3: 5-Hop Reasoning Pipeline Test
#
# This notebook tests the 5-hop reasoning pipeline implementation.
#
# ## Pipeline Overview
# 1. **Entity Grounding**: Identify financial entities (tickers, currencies)
# 2. **Financial Aspect Identification**: Identify economic drivers
# 3. **Implicit Cue Detection**: Detect hedging, euphemisms
# 4. **Implicit Sentiment Inference**: Classify sentiment (Positive/Negative/Neutral)
# 5. **Market Implication Inference**: Determine market direction (Bullish/Bearish/Uncertain)

# %% [markdown]
# ## 1. Setup and Imports

# %%
import sys
from pathlib import Path
import json
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

# Add src to path
sys.path.insert(0, str(Path().resolve().parent))

from src.pipeline import ReasoningPipeline

print("Setup complete!")
# Out:
# Setup complete!

# %% [markdown]
# ## 2. Initialize Pipeline
#
# This notebook uses **Hugging Face local** with **Flan-T5-base** (runs on your machine, no API key). Base is fast on CPU; use `flan-t5-xl` in the code below for better quality if you have GPU or time.
#
# - Install: `pip install transformers torch`
# - First run downloads the model; later runs use the cache and work offline.

# %% [markdown]
# **Quick sanity check (optional)** — Run one `generate()` in a few seconds using **flan-t5-base**.
#
# **To avoid kernel crash:** Run **either** the "Initialize Pipeline" cell **or** the cell below in one session. Loading both XL and base in the same kernel can run out of memory. For a fast test only: restart the kernel, run "Setup and Imports", then run the cell below.

# %%
from src.pipeline.llm_client import LLMClient

# Use flan-t5-xl and run one short call
llm = LLMClient(provider="huggingface_local", model="google/flan-t5-xl", max_tokens=8)
out = llm.generate("Say positive or negative:")
print("Model output:", repr(out))
print("Stats:", llm.get_usage_stats())
# Out:
# Loading weights:   0%|          | 0/558 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning

# %%
from huggingface_hub import scan_cache_dir
info = scan_cache_dir()
print(info)
# Or just the cache directory:
import os
print(os.environ.get("HF_HOME", os.path.expanduser("~/.cache/huggingface")))
# Out:
# HFCacheInfo(size_on_disk=15835076203, repos=frozenset({CachedRepoInfo(repo_id='facebook/bart-base', repo_type='model', repo_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base'), size_on_disk=560484107, nb_files=5, revisions=frozenset({CachedRevisionInfo(commit_hash='aadd2ab0ae0c8268c7c9693540e9904811f36177', snapshot_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177'), size_on_disk=560484107, files=frozenset({CachedFileInfo(file_name='tokenizer.json', file_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/tokenizer.json'), blob_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base/blobs/ad0bcbeb288f0d1373d88e0762e66357f55b8311'), size_on_disk=1355863, blob_last_accessed=1756084319.003309, blob_last_modified=1756084304.0799708), CachedFileInfo(file_name='pytorch_model.bin', file_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/pytorch_model.bin'), blob_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base/blobs/6e4fdb5e04114696ec4f7cc0cb5fc2a22a826f1c9eea234ca550b5390341a2fd'), size_on_disk=557771387, blob_last_accessed=1756084325.7076151, blob_last_modified=1756084325.1990104), CachedFileInfo(file_name='merges.txt', file_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/merges.txt'), blob_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base/blobs/226b0752cac7789c48f0cb3ec53eda48b7be36cc'), size_on_disk=456318, blob_last_accessed=1769329799.613166, blob_last_modified=1756084303.76725), CachedFileInfo(file_name='config.json', file_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/config.json'), blob_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base/blobs/7c84a2e277097ae01ff7ecc03d977a930b713058'), size_on_disk=1716, blob_last_accessed=1756084303.129669, blob_last_modified=1756084302.834831), CachedFileInfo(file_name='vocab.json', file_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/vocab.json'), blob_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--facebook--bart-base/blobs/5606f48548d99a9829d10a96cd364b816b02cd21'), size_on_disk=898823, blob_last_accessed=1769329799.61296, blob_last_modified=1756084303.4470317)}), refs=frozenset({'main'}), last_modified=1756084325.1990104)}), last_accessed=1769329799.613166, last_modified=1756084325.1990104), CachedRepoInfo(repo_id='google/flan-t5-base', repo_type='model', repo_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--google--flan-t5-base'), size_on_disk=993624646, nb_files=7, revisions=frozenset({CachedRevisionInfo(commit_hash='7bcac572ce56db69c1ea7c8af255c5d7c9672fc2', snapshot_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--google--flan-t5-base/snapshots/7bcac572ce56db69c1ea7c8af255c5d7c9672fc2'), size_on_disk=993624646, files=frozenset({CachedFileInfo(file_name='tokenizer.json', file_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--google--flan-t5-base/snapshots/7bcac572ce56db69c1ea7c8af255c5d7c9672fc2/tokenizer.json'), blob_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--google--flan-t5-base/blobs/fc669fbad1a6a82119ca3e1fa75db33ee22ca47d'), size_on_disk=2424064, blob_last_accessed=1765947332.2270274, blob_last_modified=1765947331.3977766), CachedFileInfo(file_name='config.json', file_path=PosixPath('/Users/longnguyen/.cache/huggingface/hub/models--google--flan-t5-base/snapshots/7bcac572ce56db69c1ea7c8af255c5d7c9672fc2/config.json'), ...
# /Users/longnguyen/.cache/huggingface

# %% [markdown]
# ## 3. Test with Example Headlines
#
# Let's test the pipeline with some example financial news headlines.

# %%
# Example headlines (from the dataset or similar)
test_cases = [
    {
        "text": "Euro to benefit from the ECB's pronounced hawkish determination",
        "ticker": "EURUSD",
    },
    {"text": "Bitcoin faces headwinds as regulatory concerns persist", "ticker": "BTC"},
    {
        "text": "Apple shares may see gains despite challenging market conditions",
        "ticker": "AAPL",
    },
    {
        "text": "Fed remains cautious about inflation while keeping rates steady",
        "ticker": None,
    },
]

print(f"Prepared {len(test_cases)} test cases")
# Out:
# Prepared 4 test cases

# %% [markdown]
# ## 4. Run Pipeline on Test Cases
#
# **Why it can feel slow:** Each headline runs **5 sequential model calls** (one per hop). With Flan-T5-XL (~3B params), each call can take several seconds on CPU, or ~0.5–2 s on GPU. So 4 test cases × 5 hops = **20 inferences** → a few minutes on CPU is normal. To speed up: use **GPU** (`HF_DEVICE=0`), or a **smaller model** (e.g. `google/flan-t5-base`) in the Initialize Pipeline cell.

# %%
if pipeline is None:
    print("⚠ Skipping pipeline execution - API key not set")
    print("\nTo test the pipeline structure, here's what would happen:")
    print("\n1. Entity Grounding: Identifies tickers/entities")
    print("2. Financial Aspect: Identifies economic drivers")
    print("3. Implicit Cue: Detects hedging/euphemisms")
    print("4. Sentiment Inference: Classifies sentiment")
    print("5. Market Implication: Determines market direction")
else:
    import time
    results = []

    for i, test_case in enumerate(test_cases, 1):
        print(f"\n{'=' * 60}")
        print(f"Test Case {i}: {test_case['text']}")
        print(f"{'=' * 60}")

        try:
            # Run pipeline (5 hops = 5 model calls per case)
            t0 = time.perf_counter()
            context = pipeline.run(
                text=test_case["text"], ticker=test_case.get("ticker")
            )
            elapsed = time.perf_counter() - t0

            # Get final result
            result = pipeline.get_final_result(context)
            print(f"\n  ⏱ {elapsed:.1f}s for this case (5 hops)")
            results.append(result)

            # Display results
            print("\n📊 Results:")
            print(f"  Entity: {result['entity']}")
            print(f"  Financial Aspect: {result['financial_aspect']}")
            print(f"  Implicit Cues: {result['implicit_cues']}")
            print(f"  Sentiment: {result['sentiment']}")
            print(f"  Market Implication: {result['market_implication']}")

            # Access sentiment_reasoning from nested reasoning dict
            sentiment_reasoning = result.get("reasoning", {}).get("sentiment_reasoning")
            if sentiment_reasoning:
                print("\n💭 Sentiment Reasoning:")
                print(f"  {sentiment_reasoning}")

        except Exception as e:
            print(f"❌ Error: {e}")
            import traceback

            traceback.print_exc()
# Out:
# ============================================================
# Test Case 1: Euro to benefit from the ECB's pronounced hawkish determination
# ============================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 21
#      18 try:
#      19     # Run pipeline (5 hops = 5 model calls per case)
#      20     t0 = time.perf_counter()
# ---> 21     context = pipeline.run(
#      22         text=test_case["text"], ticker=test_case.get("ticker")
#      23     )
#      24     elapsed = time.perf_counter() - t0
#      26     # Get final result
#
# File ~/Desktop/uoa-group1-c6/src/pipeline/orchestrator.py:80, in ReasoningPipeline.run(self, text, ticker, **kwargs)
#      78 for hop in self.hops:
#      79     try:
# ---> 80         context = hop.execute(context, self.llm_client, **kwargs)
#      81     except Exception as e:
#      82         # Log error but continue with next hop
#      83         context.add_hop_result(
#      84             hop.name, {"error": str(e)}, raw_response=f"Error: {str(e)}"
#      85         )
#
# File ~/Desktop/uoa-group1-c6/src/pipeline/hops/base.py:81, in BaseHop.execute(self, context, llm_client, **kwargs)
#      66 """
#      67 Execute this hop's reasoning.
#      68
#    (...)     78     Updated context with this hop's results
#      79 """
#      80 prompt = self.build_prompt(context)
# ---> 81 response = llm_client.generate(prompt, **kwargs)
#      82 parsed = self.parse_response(response, context)
#      83 return self.update_context(context, parsed, response)
#
# File ~/Desktop/uoa-group1-c6/src/pipeline/llm_client.py:470, in LLMClient.generate(self, prompt, system_prompt, **kwargs)
#     466 def generate(
#     467     self, prompt: str, system_prompt: Optional[str] = None, **kwargs: Any
#     468 ) -> str:
#     469     """Generate response from the configured LLM."""
# --> 470     return self._backend.generate(prompt, system_prompt=system_prompt, **kwargs)
#
# File ~/Desktop/uoa-group1-c6/src/pipeline/llm_client.py:347, in HuggingFaceLocalBackend.generate(self, prompt, system_prompt, **kwargs)
#     345     gen_kwargs["temperature"] = max(temperature, 1e-7)
#     346     gen_kwargs["top_p"] = top_p
# --> 347 out_ids = self._model.generate(**inputs, **gen_kwargs)
#     348 text = self._tokenizer.decode(out_ids[0], skip_special_tokens=True)
#     349 # For seq2seq, decode includes input in some setups; strip to generated part only if needed
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/transformers/generation/utils.py:2638, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2635 model_kwargs["use_cache"] = generation_config.use_cache
#    2637 # 9. Call generation mode
# -> 2638 result = decoding_method(
#    2639     self,
#    2640     input_ids,
#    2641     logits_processor=prepared_logits_processor,
#    2642     stopping_criteria=prepared_stopping_criteria,
#    2643     generation_config=generation_config,
#    2644     **generation_mode_kwargs,
#    2645     **model_kwargs,
#    2646 )
#    2648 return result
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/transformers/generation/utils.py:2843, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2841     model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2842     with self._optimize_model_for_decode():
# -> 2843         outputs = model_forward(**model_inputs, return_dict=True)
#    2844 prefill_consumed = True
#    2845 model_kwargs = self._update_model_kwargs_for_generation(
#    2846     outputs,
#    2847     model_kwargs,
#    2848     is_encoder_decoder=self.config.is_encoder_decoder,
#    2849 )
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/transformers/models/t5/modeling_t5.py:1123, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **kwargs)
#    1120     decoder_input_ids = self._shift_right(labels)
#    1122 # Decode
# -> 1123 decoder_outputs = self.decoder(
#    1124     input_ids=decoder_input_ids,
#    1125     attention_mask=decoder_attention_mask,
#    1126     inputs_embeds=decoder_inputs_embeds,
#    1127     past_key_values=past_key_values,
#    1128     encoder_hidden_states=hidden_states,
#    1129     encoder_attention_mask=attention_mask,
#    1130     use_cache=use_cache,
#    1131     output_attentions=output_attentions,
#    1132     output_hidden_states=output_hidden_states,
#    1133     return_dict=return_dict,
#    1134     cache_position=cache_position,
#    1135 )
#    1137 sequence_output = decoder_outputs[0]
#    1139 if self.config.scale_decoder_outputs:
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/transformers/models/t5/modeling_t5.py:767, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **kwargs)
#     764 if output_hidden_states:
#     765     all_hidden_states = all_hidden_states + (hidden_states,)
# --> 767 layer_outputs = layer_module(
#     768     hidden_states,
#     769     attention_mask,
#     770     position_bias,
#     771     encoder_hidden_states,
#     772     encoder_extended_attention_mask,
#     773     encoder_decoder_position_bias,  # as a positional argument for gradient checkpointing
#     774     past_key_values=past_key_values,
#     775     use_cache=use_cache,
#     776     output_attentions=output_attentions,
#     777     return_dict=return_dict,
#     778     cache_position=cache_position,
#     779 )
#     781 hidden_states = layer_outputs[0]
#     783 # We share the position biases between the layers - the first layer store them
#     784 # layer_outputs = hidden-states, key-value-states (self-attention position bias), (self-attention weights),
#     785 # (cross-attention position bias), (cross-attention weights)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/transformers/modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         logger.warning_once(message)
#      92     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93 return super().__call__(*args, **kwargs)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/transformers/models/t5/modeling_t5.py:454, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, past_key_values, use_cache, output_attentions, return_dict, cache_position)
#     440 def forward(
#     441     self,
#     442     hidden_states,
#    (...)    452     cache_position=None,
#     453 ):
# --> 454     self_attention_outputs = self.layer[0](
#     455         hidden_states,
#     456         attention_mask=attention_mask,
#     457         position_bias=position_bias,
#     458         past_key_values=past_key_values,
#     459         use_cache=use_cache,
#     460         output_attentions=output_attentions,
#     461         cache_position=cache_position,
#     462     )
#     463     hidden_states = self_attention_outputs[0]
#     464     attention_outputs = self_attention_outputs[1:]  # Keep self-attention outputs and relative position weights
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/transformers/models/t5/modeling_t5.py:377, in T5LayerSelfAttention.forward(self, hidden_states, attention_mask, position_bias, past_key_values, use_cache, output_attentions, cache_position)
#     366 def forward(
#     367     self,
#     368     hidden_states,
#    (...)    374     cache_position=None,
#     375 ):
#     376     normed_hidden_states = self.layer_norm(hidden_states)
# --> 377     attention_output = self.SelfAttention(
#     378         normed_hidden_states,
#     379         mask=attention_mask,
#     380         position_bias=position_bias,
#     381         past_key_values=past_key_values,
#     382         use_cache=use_cache,
#     383         output_attentions=output_attentions,
#     384         cache_position=cache_position,
#     385     )
#     386     hidden_states = hidden_states + self.dropout(attention_output[0])
#     387     outputs = (hidden_states,) + attention_output[1:]  # add attentions if we output them
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/transformers/models/t5/modeling_t5.py:348, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_values, query_length, use_cache, output_attentions, cache_position)
#     346 attn_output = attn_output.transpose(1, 2).contiguous()
#     347 attn_output = attn_output.view(batch_size, -1, self.inner_dim)
# --> 348 attn_output = self.o(attn_output)
#     350 outputs = (attn_output, position_bias)
#     352 if output_attentions:
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5. Detailed Results Analysis

# %%
if pipeline is not None and "results" in locals() and results:
    # Create DataFrame for easier analysis
    df_results = pd.DataFrame(
        [
            {
                "text": r["text"],
                "entity": r["entity"],
                "financial_aspect": r["financial_aspect"],
                "sentiment": r["sentiment"],
                "market_implication": r["market_implication"],
                "implicit_cues_count": len(r["implicit_cues"])
                if r["implicit_cues"]
                else 0,
            }
            for r in results
        ]
    )

    print("\n📋 Summary Table:")
    display(df_results)

    # Show detailed reasoning for first result
    if results:
        print("\n🔍 Detailed Reasoning (First Case):")
        first_result = results[0]
        print(json.dumps(first_result["reasoning"], indent=2))
# Out:
# 📋 Summary Table:
#                                                 text   entity  \
# 0  Euro to benefit from the ECB's pronounced hawk...      EUR
# 1  Bitcoin faces headwinds as regulatory concerns...  Bitcoin
# 2  Apple shares may see gains despite challenging...     AAPL
# 3  Fed remains cautious about inflation while kee...      Fed
#
#       financial_aspect sentiment market_implication  implicit_cues_count
# 0      Monetary policy  Positive            Bullish                    1
# 1  regulatory concerns  Negative            Bearish                    2
# 2    corporate factors  Positive            Bullish                    2
# 3            inflation   Neutral          Uncertain                    2
# 🔍 Detailed Reasoning (First Case):
# {
#   "entity_reasoning": "The headline mentions the Euro (EUR) as the currency to benefit from the European Central Bank's (ECB) hawkish determination.",
#   "aspect_reasoning": "The headline mentions the European Central Bank's (ECB) hawkish determination, indicating a potential shift in monetary policy. This could impact the value of the Euro and influence market sentiment towards the currency.",
#   "cue_reasoning": "The use of 'pronounced hawkish determination' is a euphemism that suggests a strong and aggressive stance by the ECB, without explicitly stating it. This indirect language implies a positive outlook for the Euro without directly stating it.",
#   "sentiment_reasoning": "The headline suggests that the Euro will benefit from the European Central Bank's (ECB) hawkish determination. The term 'pronounced hawkish determination' implies that the ECB is taking a strong stance towards tightening monetary policy, which is typically viewed positively by investors. This indicates that the Euro is expected to strengthen as a result of the ECB's actions, leading to a positive sentiment.",
#   "market_reasoning": "The headline indicates that the Euro is expected to benefit from the European Central Bank's (ECB) pronounced hawkish determination. This suggests that the ECB is likely to take a more aggressive stance on monetary policy, potentially raising interest rates or tightening monetary policy to combat inflation. This could attract investors to the Euro, leading to an upward price movement. The strong positive sentiment in the headline further supports the bullish market implication."
# }

# %% [markdown]
# ## 6. Inspect Individual Hop Results

# %%
if pipeline is not None and "results" in locals() and results:
    # Show all hop results for first test case
    first_result = results[0]

    print("Individual Hop Results:")
    print("=" * 60)

    for hop_name, hop_result in first_result["all_hop_results"].items():
        print(f"\n{hop_name.upper().replace('_', ' ')}:")
        print(json.dumps(hop_result, indent=2))
# Out:
# Individual Hop Results:
# ============================================================
#
# ENTITY GROUNDING:
# {
#   "entities": [
#     "EUR",
#     "ECB"
#   ],
#   "primary_entity": "EUR",
#   "confidence": "high",
#   "reasoning": "The headline mentions the Euro (EUR) as the currency to benefit from the European Central Bank's (ECB) hawkish determination."
# }
#
# FINANCIAL ASPECT:
# {
#   "aspects": [
#     "Monetary policy"
#   ],
#   "primary_aspect": "Monetary policy",
#   "reasoning": "The headline mentions the European Central Bank's (ECB) hawkish determination, indicating a potential shift in monetary policy. This could impact the value of the Euro and influence market sentiment towards the currency."
# }
#
# IMPLICIT CUE:
# {
#   "cues": [
#     "pronounced hawkish determination"
#   ],
#   "cue_types": [
#     "euphemism"
#   ],
#   "has_implicit_language": true,
#   "reasoning": "The use of 'pronounced hawkish determination' is a euphemism that suggests a strong and aggressive stance by the ECB, without explicitly stating it. This indirect language implies a positive outlook for the Euro without directly stating it."
# }
#
# SENTIMENT INFERENCE:
# {
#   "sentiment": "Positive",
#   "sentiment_score": null,
#   "reasoning": "The headline suggests that the Euro will benefit from the European Central Bank's (ECB) hawkish determination. The term 'pronounced hawkish determination' implies that the ECB is taking a strong stance towards tightening monetary policy, which is typically viewed positively by investors. This indicates that the Euro is expected to strengthen as a result of the ECB's actions, leading to a positive sentiment."
# }
#
# MARKET IMPLICATION:
# {
#   "market_implication": "Bullish",
#   "reasoning": "The headline indicates that the Euro is expected to benefit from the European Central Bank's (ECB) pronounced hawkish determination. This suggests that the ECB is likely to take a more aggressive stance on monetary policy, potentially raising interest rates or tightening monetary policy to combat inflation. This could attract investors to the Euro, leading to an upward price movement. The strong positive sentiment in the headline further supports the bullish market implication."
# }

# %% [markdown]
# ## 7. Usage Statistics

# %%
if pipeline is not None:
    stats = pipeline.get_usage_stats()

    print("LLM Usage Statistics:")
    print("=" * 60)
    print(f"Total API Calls: {stats['total_calls']}")
    print(f"Prompt Tokens: {stats['total_prompt_tokens']:,}")
    print(f"Completion Tokens: {stats['total_completion_tokens']:,}")
    print(f"Total Tokens: {stats['total_tokens']:,}")

    # Estimate cost (GPT-3.5-turbo pricing)
    input_cost_per_1k = 0.0015
    output_cost_per_1k = 0.002

    estimated_cost = (stats["total_prompt_tokens"] / 1000 * input_cost_per_1k) + (
        stats["total_completion_tokens"] / 1000 * output_cost_per_1k
    )

    print(f"\nEstimated Cost: ${estimated_cost:.4f}")
    print("   (Based on GPT-3.5-turbo pricing)")
# Out:
# LLM Usage Statistics:
# ============================================================
# Total API Calls: 20
# Prompt Tokens: 3,887
# Completion Tokens: 1,574
# Total Tokens: 5,461
#
# Estimated Cost: $0.0090
#    (Based on GPT-3.5-turbo pricing)

# %% [markdown]
# ## 8. Test with Real Data
#
# Test the pipeline with actual data from the dataset.

# %%
# Load actual data from the dataset
from src.utils.data_loader import load_all_dataframes

base_path = Path().resolve().parent
data = load_all_dataframes(base_path)

if "ground_truth" in data:
    df_gt = data["ground_truth"]

    # Sample a few headlines
    sample_size = 3
    sample_df = df_gt.sample(n=min(sample_size, len(df_gt)), random_state=42)

    print(f"Testing with {len(sample_df)} real headlines from dataset:\n")

    if pipeline is not None:
        real_results = []

        for idx, row in sample_df.iterrows():
            text = row.get("title", row.get("text", ""))
            ticker = row.get("ticker")
            true_sentiment = row.get("true_sentiment", "Unknown")

            print(f"\n{'=' * 60}")
            print(f"Headline: {text}")
            print(f"Ticker: {ticker}")
            print(f"True Sentiment: {true_sentiment}")
            print(f"{'=' * 60}")

            try:
                context = pipeline.run(text=text, ticker=ticker)
                result = pipeline.get_final_result(context)

                print("\n📊 Pipeline Results:")
                print(f"  Predicted Sentiment: {result['sentiment']}")
                print(f"  Market Implication: {result['market_implication']}")

                # Compare with ground truth
                if true_sentiment:
                    from src.utils.sentiment_encoding import to_text

                    true_sentiment_text = (
                        to_text(true_sentiment)
                        if isinstance(true_sentiment, (int, float))
                        else str(true_sentiment)
                    )
                    match = "✓" if result["sentiment"] == true_sentiment_text else "✗"
                    print(f"  {match} Ground Truth: {true_sentiment_text}")

                real_results.append(
                    {
                        "text": text,
                        "ticker": ticker,
                        "true_sentiment": true_sentiment_text
                        if "true_sentiment_text" in locals()
                        else true_sentiment,
                        "predicted_sentiment": result["sentiment"],
                        "market_implication": result["market_implication"],
                    }
                )

            except Exception as e:
                print(f"❌ Error: {e}")

        if real_results:
            print("\n\n📋 Summary of Real Data Tests:")
            df_real = pd.DataFrame(real_results)
            display(df_real)
    else:
        print("⚠ Pipeline not initialized. Run the 'Initialize Pipeline' cell above.")
else:
    print("⚠ Ground truth data not found.")
# Out:
# Loaded ground truth: 2291 rows
# Loaded single article predictions: 2291 rows
# Loaded all-day articles: 293 rows
# Testing with 3 real headlines from dataset:
#
#
# ============================================================
# Headline: USDJPY Next on the upside comes 13790 – UOB
# Ticker: USDJPY
# True Sentiment: Positive
# ============================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 31
#      28 print(f"{'='*60}")
#      30 try:
# ---> 31     context = pipeline.run(text=text, ticker=ticker)
#      32     result = pipeline.get_final_result(context)
#      34     print(f"\n📊 Pipeline Results:")
#
# File ~/Desktop/uoa-group1-c6/src/pipeline/orchestrator.py:83, in ReasoningPipeline.run(self, text, ticker, **kwargs)
#      81 for hop in self.hops:
#      82     try:
# ---> 83         context = hop.execute(context, self.llm_client, **kwargs)
#      84     except Exception as e:
#      85         # Log error but continue with next hop
#      86         context.add_hop_result(
#      87             hop.name,
#      88             {"error": str(e)},
#      89             raw_response=f"Error: {str(e)}"
#      90         )
#
# File ~/Desktop/uoa-group1-c6/src/pipeline/hops/entity_grounding.py:124, in EntityGroundingHop.execute(self, context, llm_client, **kwargs)
#     121 prompt = self.build_prompt(context)
#     123 # Call LLM
# --> 124 response = llm_client.generate(prompt, **kwargs)
#     126 # Parse and update context
#     127 parsed = self.parse_response(response, context)
#
# File ~/Desktop/uoa-group1-c6/src/pipeline/llm_client.py:99, in LLMClient.generate(self, prompt, system_prompt, **kwargs)
#      97 for attempt in range(self.max_retries):
#      98     try:
# ---> 99         response = self.client.chat.completions.create(**params)
#     101         # Track tokens
#     102         usage = response.usage
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)   1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/openai/_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Desktop/uoa-group1-c6/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/.local/share/uv/python/cpython-3.13.5-macos-aarch64-none/lib/python3.13/ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File ~/.local/share/uv/python/cpython-3.13.5-macos-aarch64-none/lib/python3.13/ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 9. Pipeline Architecture Overview
#
# Visualize how the pipeline works:

# %%
print("""
5-Hop Reasoning Pipeline Architecture
=====================================

Input: Financial News Headline
  │
  ├─→ [Hop 1] Entity Grounding
  │     └─→ Identifies: Tickers, Currencies, Assets
  │
  ├─→ [Hop 2] Financial Aspect Identification
  │     └─→ Identifies: Inflation, Rates, Growth, Risk, etc.
  │
  ├─→ [Hop 3] Implicit Cue Detection
  │     └─→ Detects: Hedging, Euphemisms, Indirect Language
  │
  ├─→ [Hop 4] Implicit Sentiment Inference
  │     └─→ Classifies: Positive / Negative / Neutral
  │
  └─→ [Hop 5] Market Implication Inference
        └─→ Determines: Bullish / Bearish / Uncertain

Output: Complete reasoning with all intermediate steps

Context Passing:
  Each hop receives context from previous hops and adds its own results.
  This allows later hops to use information from earlier hops.
""")
# Out:
# 5-Hop Reasoning Pipeline Architecture
# =====================================
#
# Input: Financial News Headline
#   │
#   ├─→ [Hop 1] Entity Grounding
#   │     └─→ Identifies: Tickers, Currencies, Assets
#   │
#   ├─→ [Hop 2] Financial Aspect Identification
#   │     └─→ Identifies: Inflation, Rates, Growth, Risk, etc.
#   │
#   ├─→ [Hop 3] Implicit Cue Detection
#   │     └─→ Detects: Hedging, Euphemisms, Indirect Language
#   │
#   ├─→ [Hop 4] Implicit Sentiment Inference
#   │     └─→ Classifies: Positive / Negative / Neutral
#   │
#   └─→ [Hop 5] Market Implication Inference
#         └─→ Determines: Bullish / Bearish / Uncertain
#
# Output: Complete reasoning with all intermediate steps
#
# Context Passing:
#   Each hop receives context from previous hops and adds its own results.
#   This allows later hops to use information from earlier hops.
